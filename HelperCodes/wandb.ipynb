# %%
import wandb
import re
import pandas as pd

# %%
# !wandb login --relogin 320a98c6a9ba9e09b5d88d9b64059d763ae265f4
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /home/influx/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
api = wandb.Api()
# Out:
# wandb: Currently logged in as: matinazami2003 (influx_m) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
runs = api.runs("influx_m/RL-DOW30-4SUB-final")

# %%
# Only keep these fields
wanted_fields = [
    "Start",
    "End",
    "Annualized Return [%]",
    "Annualized Volatility [%]",
    "Max Drawdown [%]",
    "Average Drawdown [%]",
    "Sharpe Ratio",
    "Sortino Ratio",
    "Calmar Ratio",
    "Max Drawdown Duration (days)",
    "Number of Trades"
]

# %%
def summarize_runs(pattern: str):
    regex = re.compile(pattern)

    data = []
    for run in runs:
        if regex.match(run.name):
            res_trade = run.summary.get("res_trade", {})
            trade_metrics = run.summary.get("trade_metrics", {})
            row = {field: res_trade.get(field) for field in wanted_fields if field in res_trade}
            row["Number of Trades"] = trade_metrics.get("Number of Trades")
            data.append(row)

    df = pd.DataFrame(data)

    if df.empty:
        print("No runs matched the pattern.")
        return

    means = df.mean(numeric_only=True)
    stds = df.std(numeric_only=True)

    for field in wanted_fields:
        if field in df.columns:
            if pd.api.types.is_numeric_dtype(df[field]):
                print(f"{field}: {means[field]:.2f} ± {stds[field]:.2f}")
            else:
                print(f"{field}: {df[field].unique()}")

    # Add number of runs matched
    print(f"\nTotal runs matched: {len(data)}")

# %%
summarize_runs(r"^init ppo .* 1 False$")
# Out:
# Start: ['2023-01-03T00:00:00']
# End: ['2025-08-29T00:00:00']
# Annualized Return [%]: 25.65 ± 4.47
# Annualized Volatility [%]: 20.46 ± 1.07
# Max Drawdown [%]: -24.78 ± 1.82
# Average Drawdown [%]: -5.33 ± 0.57
# Sharpe Ratio: 1.22 ± 0.19
# Sortino Ratio: 1.58 ± 0.24
# Calmar Ratio: 1.04 ± 0.19
# Max Drawdown Duration (days): 127.60 ± 19.68
# Number of Trades: 122.50 ± 58.41
#
# Total runs matched: 10

# %%
summarize_runs(r"^init ppo .* 1 True$")
# Out:
# Start: ['2023-01-03T00:00:00']
# End: ['2025-08-29T00:00:00']
# Annualized Return [%]: 21.35 ± 4.97
# Annualized Volatility [%]: 19.25 ± 2.13
# Max Drawdown [%]: -23.43 ± 1.94
# Average Drawdown [%]: -6.05 ± 1.58
# Sharpe Ratio: 1.11 ± 0.22
# Sortino Ratio: 1.48 ± 0.29
# Calmar Ratio: 0.91 ± 0.20
# Max Drawdown Duration (days): 182.70 ± 88.75
# Number of Trades: 124.70 ± 47.89
#
# Total runs matched: 10

# %%
summarize_runs(r"^init ppo .* 3 False$")
# Out:
# Start: ['2023-01-03T00:00:00']
# End: ['2025-08-29T00:00:00']
# Annualized Return [%]: 19.10 ± 3.98
# Annualized Volatility [%]: 21.25 ± 1.35
# Max Drawdown [%]: -24.33 ± 2.20
# Average Drawdown [%]: -7.79 ± 1.21
# Sharpe Ratio: 0.93 ± 0.14
# Sortino Ratio: 1.24 ± 0.18
# Calmar Ratio: 0.79 ± 0.18
# Max Drawdown Duration (days): 250.20 ± 108.01
# Number of Trades: 139.60 ± 11.89
#
# Total runs matched: 5

# %%
summarize_runs(r"^init ppo .* 3 True$")
# Out:
# Start: ['2023-01-03T00:00:00']
# End: ['2025-08-29T00:00:00']
# Annualized Return [%]: 20.89 ± 4.75
# Annualized Volatility [%]: 19.21 ± 2.86
# Max Drawdown [%]: -23.24 ± 2.86
# Average Drawdown [%]: -5.62 ± 1.48
# Sharpe Ratio: 1.09 ± 0.16
# Sortino Ratio: 1.45 ± 0.20
# Calmar Ratio: 0.90 ± 0.15
# Max Drawdown Duration (days): 154.25 ± 69.62
# Number of Trades: 154.00 ± 33.93
#
# Total runs matched: 4

# %%
summarize_runs(r"^init ppo .* 1 False risk-reward$")
# Out:
# Start: ['2023-01-03T00:00:00']
# End: ['2025-08-29T00:00:00']
# Annualized Return [%]: 24.38 ± 8.64
# Annualized Volatility [%]: 20.52 ± 1.45
# Max Drawdown [%]: -25.03 ± 0.82
# Average Drawdown [%]: -6.26 ± 2.13
# Sharpe Ratio: 1.16 ± 0.35
# Sortino Ratio: 1.55 ± 0.47
# Calmar Ratio: 0.97 ± 0.33
# Max Drawdown Duration (days): 192.00 ± 113.68
# Number of Trades: 127.80 ± 47.99
#
# Total runs matched: 5

# %%
summarize_runs(r"^init ppo .* 3 False risk-reward$")
# Out:
# Start: ['2023-01-03T00:00:00' nan]
# End: ['2025-08-29T00:00:00' nan]
# Annualized Return [%]: 21.97 ± 8.12
# Annualized Volatility [%]: 20.84 ± 1.39
# Max Drawdown [%]: -25.33 ± 0.92
# Average Drawdown [%]: -6.44 ± 2.55
# Sharpe Ratio: 1.05 ± 0.31
# Sortino Ratio: 1.40 ± 0.40
# Calmar Ratio: 0.86 ± 0.30
# Max Drawdown Duration (days): 214.50 ± 134.69
# Number of Trades: 135.75 ± 38.51
#
# Total runs matched: 5

# %%
summarize_runs(r"^init rppo .* 1 False$")
# Out:
# Start: ['2023-01-03T00:00:00']
# End: ['2025-08-29T00:00:00']
# Annualized Return [%]: 22.67 ± 5.21
# Annualized Volatility [%]: 19.68 ± 1.73
# Max Drawdown [%]: -24.53 ± 1.58
# Average Drawdown [%]: -5.85 ± 1.62
# Sharpe Ratio: 1.14 ± 0.23
# Sortino Ratio: 1.53 ± 0.31
# Calmar Ratio: 0.93 ± 0.21
# Max Drawdown Duration (days): 175.00 ± 99.07
# Number of Trades: 85.30 ± 30.01
#
# Total runs matched: 10

# %%
summarize_runs(r"^init rppo .* 1 True$")
# Out:
# Start: ['2023-01-03T00:00:00' nan]
# End: ['2025-08-29T00:00:00' nan]
# Annualized Return [%]: 22.05 ± 3.40
# Annualized Volatility [%]: 19.05 ± 1.94
# Max Drawdown [%]: -24.13 ± 1.45
# Average Drawdown [%]: -5.57 ± 1.36
# Sharpe Ratio: 1.16 ± 0.20
# Sortino Ratio: 1.56 ± 0.26
# Calmar Ratio: 0.92 ± 0.16
# Max Drawdown Duration (days): 142.33 ± 58.01
# Number of Trades: 112.17 ± 35.53
#
# Total runs matched: 7

# %%
summarize_runs(r"^init rppo .* 3 False$")
# Out:
# Start: ['2023-01-03T00:00:00']
# End: ['2025-08-29T00:00:00']
# Annualized Return [%]: 28.62 ± 2.23
# Annualized Volatility [%]: 19.60 ± 1.69
# Max Drawdown [%]: -25.11 ± 2.97
# Average Drawdown [%]: -4.48 ± 0.40
# Sharpe Ratio: 1.39 ± 0.04
# Sortino Ratio: 1.83 ± 0.11
# Calmar Ratio: 1.14 ± 0.06
# Max Drawdown Duration (days): 99.80 ± 8.84
# Number of Trades: 89.80 ± 36.19
#
# Total runs matched: 5

# %%
summarize_runs(r"init rppo .* 3 True$")
# Out:
# Start: ['2023-01-03T00:00:00' nan]
# End: ['2025-08-29T00:00:00' nan]
# Annualized Return [%]: 25.26 ± 6.75
# Annualized Volatility [%]: 19.52 ± 1.06
# Max Drawdown [%]: -24.32 ± 1.56
# Average Drawdown [%]: -5.24 ± 1.89
# Sharpe Ratio: 1.26 ± 0.33
# Sortino Ratio: 1.71 ± 0.46
# Calmar Ratio: 1.04 ± 0.31
# Max Drawdown Duration (days): 146.00 ± 94.41
# Number of Trades: 75.00 ± 65.87
#
# Total runs matched: 4

# %%
summarize_runs(r"^init rppo .* 1 False risk-reward$")
# Out:
# Start: ['2023-01-03T00:00:00']
# End: ['2025-08-29T00:00:00']
# Annualized Return [%]: 25.47 ± 4.32
# Annualized Volatility [%]: 20.18 ± 1.94
# Max Drawdown [%]: -25.33 ± 2.01
# Average Drawdown [%]: -5.21 ± 0.72
# Sharpe Ratio: 1.23 ± 0.17
# Sortino Ratio: 1.64 ± 0.26
# Calmar Ratio: 1.00 ± 0.11
# Max Drawdown Duration (days): 120.60 ± 24.14
# Number of Trades: 85.80 ± 39.42
#
# Total runs matched: 5

# %%
summarize_runs(r"^init rppo .* 3 False risk-reward$")
# Out:
# Start: ['2023-01-03T00:00:00' nan]
# End: ['2025-08-29T00:00:00' nan]
# Annualized Return [%]: 27.01 ± 3.13
# Annualized Volatility [%]: 19.48 ± 1.33
# Max Drawdown [%]: -25.46 ± 2.07
# Average Drawdown [%]: -4.90 ± 0.68
# Sharpe Ratio: 1.33 ± 0.12
# Sortino Ratio: 1.79 ± 0.18
# Calmar Ratio: 1.06 ± 0.04
# Max Drawdown Duration (days): 117.25 ± 15.95
# Number of Trades: 119.25 ± 31.69
#
# Total runs matched: 5

# %%
best = []
for run in runs:
    res_trade = run.summary.get("res_trade", {})
    trade_metrics = run.summary.get("trade_metrics", {})
    row = {field: res_trade.get(field) for field in wanted_fields if field in res_trade}
    if 'Annualized Return [%]' in row:
        best.append((row['Annualized Return [%]'], run.name, row))
    row["Number of Trades"] = trade_metrics.get("Number of Trades")

# %%
best.sort()
best = list(reversed(best))

# %%
best
# Out:
# [(35.169709976361304,
#   'init ppo 8 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 35.169709976361304,
#    'Annualized Volatility [%]': 21.21322876470389,
#    'Max Drawdown [%]': -25.34914648279225,
#    'Average Drawdown [%]': -4.8373454651483945,
#    'Sharpe Ratio': 1.5303760750095827,
#    'Sortino Ratio': 1.9980492091333124,
#    'Calmar Ratio': 1.387411998279135,
#    'Max Drawdown Duration (days)': 103,
#    'Number of Trades': 132}),
#  (33.90782175234646,
#   'init ppo 5 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 33.90782175234646,
#    'Annualized Volatility [%]': 22.12884399318141,
#    'Max Drawdown [%]': -26.075984851644236,
#    'Average Drawdown [%]': -4.5975205827425825,
#    'Sharpe Ratio': 1.432827118432097,
#    'Sortino Ratio': 1.9430151883289384,
#    'Calmar Ratio': 1.3003467345628703,
#    'Max Drawdown Duration (days)': 103,
#    'Number of Trades': 126}),
#  (31.757013228068764,
#   'init ppo 5 1',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 31.757013228068764,
#    'Annualized Volatility [%]': 19.64169272251899,
#    'Max Drawdown [%]': -19.330872489743605,
#    'Average Drawdown [%]': -4.126206329585813,
#    'Sharpe Ratio': 1.5054651227249842,
#    'Sortino Ratio': 2.106062153460733,
#    'Calmar Ratio': 1.6428132379910998,
#    'Max Drawdown Duration (days)': 103,
#    'Number of Trades': 155}),
#  (31.31094618547727,
#   'init rppo 5 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 31.31094618547727,
#    'Annualized Volatility [%]': 20.568429591120772,
#    'Max Drawdown [%]': -27.78702606795158,
#    'Average Drawdown [%]': -4.732719932515637,
#    'Sharpe Ratio': 1.43028199035609,
#    'Sortino Ratio': 1.9778261790092135,
#    'Calmar Ratio': 1.126818901342956,
#    'Max Drawdown Duration (days)': 108,
#    'Number of Trades': 120}),
#  (31.28125076669428,
#   'init ppo 3 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 31.28125076669428,
#    'Annualized Volatility [%]': 18.736076381893017,
#    'Max Drawdown [%]': -24.61436511455882,
#    'Average Drawdown [%]': -4.267262393039877,
#    'Sharpe Ratio': 1.5500706033944267,
#    'Sortino Ratio': 2.0526869805554098,
#    'Calmar Ratio': 1.2708534476151143,
#    'Max Drawdown Duration (days)': 108,
#    'Number of Trades': 162}),
#  (30.841394185513813,
#   'init rppo 3 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 30.841394185513813,
#    'Annualized Volatility [%]': 20.31607066639417,
#    'Max Drawdown [%]': -27.653748530300295,
#    'Average Drawdown [%]': -4.6957898104085825,
#    'Sharpe Ratio': 1.4278959343339157,
#    'Sortino Ratio': 1.9513405616336037,
#    'Calmar Ratio': 1.1152699299236342,
#    'Max Drawdown Duration (days)': 108,
#    'Number of Trades': 105}),
#  (30.38817470310411,
#   'init rppo 2 3 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 30.38817470310411,
#    'Annualized Volatility [%]': 20.43041675365319,
#    'Max Drawdown [%]': -27.80345020414796,
#    'Average Drawdown [%]': -4.829025040591292,
#    'Sharpe Ratio': 1.4039862032916866,
#    'Sortino Ratio': 1.9232944982622069,
#    'Calmar Ratio': 1.0929641637990144,
#    'Max Drawdown Duration (days)': 108,
#    'Number of Trades': 142}),
#  (30.30876536175471,
#   'init ppo 1 3 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 30.30876536175471,
#    'Annualized Volatility [%]': 22.116764363408357,
#    'Max Drawdown [%]': -26.06825550989625,
#    'Average Drawdown [%]': -4.907151114529311,
#    'Sharpe Ratio': 1.3106745307626717,
#    'Sortino Ratio': 1.755910950723051,
#    'Calmar Ratio': 1.1626694908774635,
#    'Max Drawdown Duration (days)': 99,
#    'Number of Trades': 126}),
#  (30.16004923089397,
#   'init rppo 4 3 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 30.16004923089397,
#    'Annualized Volatility [%]': 18.402878399689097,
#    'Max Drawdown [%]': -22.678496207993796,
#    'Average Drawdown [%]': -3.7580106348562023,
#    'Sharpe Ratio': 1.527850191420416,
#    'Sortino Ratio': 2.103895541886817,
#    'Calmar Ratio': 1.3298963456079178,
#    'Max Drawdown Duration (days)': 93,
#    'Number of Trades': 57}),
#  (30.04683303942248,
#   'init rppo 9 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 30.04683303942248,
#    'Annualized Volatility [%]': 20.334939920060037,
#    'Max Drawdown [%]': -25.36573813640817,
#    'Average Drawdown [%]': -4.710348243204692,
#    'Sharpe Ratio': 1.3969395656850383,
#    'Sortino Ratio': 1.860373300265335,
#    'Calmar Ratio': 1.1845440049030311,
#    'Max Drawdown Duration (days)': 105,
#    'Number of Trades': 75}),
#  (29.554603256553168,
#   'init ppo 10 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 29.554603256553168,
#    'Annualized Volatility [%]': 20.54478899420352,
#    'Max Drawdown [%]': -24.841992648305897,
#    'Average Drawdown [%]': -4.900237880337792,
#    'Sharpe Ratio': 1.3664130094879852,
#    'Sortino Ratio': 1.761021609897638,
#    'Calmar Ratio': 1.189703405639187,
#    'Max Drawdown Duration (days)': 93,
#    'Number of Trades': 57}),
#  (29.445274559064423,
#   'init rppo 3 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 29.445274559064423,
#    'Annualized Volatility [%]': 20.460203954501356,
#    'Max Drawdown [%]': -27.80422794414359,
#    'Average Drawdown [%]': -4.651515477130318,
#    'Sharpe Ratio': 1.3666330311749828,
#    'Sortino Ratio': 1.8922561564957316,
#    'Calmar Ratio': 1.0590214775327536,
#    'Max Drawdown Duration (days)': 108,
#    'Number of Trades': 125}),
#  (29.41569413508065,
#   'init rppo 5 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 29.41569413508065,
#    'Annualized Volatility [%]': 20.71097614285909,
#    'Max Drawdown [%]': -26.107352501044968,
#    'Average Drawdown [%]': -4.8420035082964725,
#    'Sharpe Ratio': 1.3517414865373312,
#    'Sortino Ratio': 1.7735152411973774,
#    'Calmar Ratio': 1.126720686592149,
#    'Max Drawdown Duration (days)': 90,
#    'Number of Trades': 30}),
#  (29.39463502020574,
#   'init ppo 2 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 29.39463502020574,
#    'Annualized Volatility [%]': 17.844549406344196,
#    'Max Drawdown [%]': -24.28816275858581,
#    'Average Drawdown [%]': -4.16118008323642,
#    'Sharpe Ratio': 1.5372691855578713,
#    'Sortino Ratio': 1.960748991533548,
#    'Calmar Ratio': 1.2102453080694549,
#    'Max Drawdown Duration (days)': 112,
#    'Number of Trades': 142}),
#  (29.389054895241685,
#   'init rppo 4 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 29.389054895241685,
#    'Annualized Volatility [%]': 21.0205389851263,
#    'Max Drawdown [%]': -25.594347807412376,
#    'Average Drawdown [%]': -4.601284735507734,
#    'Sharpe Ratio': 1.3341060748830964,
#    'Sortino Ratio': 1.693364828951627,
#    'Calmar Ratio': 1.1482634805302725,
#    'Max Drawdown Duration (days)': 100,
#    'Number of Trades': 63}),
#  (29.150479941164843,
#   'init rppo 1 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 29.150479941164843,
#    'Annualized Volatility [%]': 18.904213973395606,
#    'Max Drawdown [%]': -23.317789509463346,
#    'Average Drawdown [%]': -4.205434889447354,
#    'Sharpe Ratio': 1.4513558631973136,
#    'Sortino Ratio': 1.8279466861595624,
#    'Calmar Ratio': 1.2501390806934916,
#    'Max Drawdown Duration (days)': 91,
#    'Number of Trades': 79}),
#  (28.898693190046455,
#   'init rppo 3 3 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 28.898693190046455,
#    'Annualized Volatility [%]': 19.426113300529934,
#    'Max Drawdown [%]': -26.572055960367763,
#    'Average Drawdown [%]': -4.639580752126471,
#    'Sharpe Ratio': 1.4070481355066375,
#    'Sortino Ratio': 1.92724355211831,
#    'Calmar Ratio': 1.0875595487661502,
#    'Max Drawdown Duration (days)': 108,
#    'Number of Trades': 109}),
#  (28.489843652156765,
#   'init rppo 2 6 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 28.489843652156765,
#    'Annualized Volatility [%]': 21.536973631432826,
#    'Max Drawdown [%]': -26.068060881707293,
#    'Average Drawdown [%]': -4.81956946893409,
#    'Sharpe Ratio': 1.2746040311650335,
#    'Sortino Ratio': 1.693630457058915,
#    'Calmar Ratio': 1.0929022983887884,
#    'Max Drawdown Duration (days)': 105,
#    'Number of Trades': 37}),
#  (28.05905267105025,
#   'init rppo 1 3 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 28.05905267105025,
#    'Annualized Volatility [%]': 19.636447210541785,
#    'Max Drawdown [%]': -25.780782489491855,
#    'Average Drawdown [%]': -4.603764129299031,
#    'Sharpe Ratio': 1.3608430421951925,
#    'Sortino Ratio': 1.812028381727699,
#    'Calmar Ratio': 1.0883708701427897,
#    'Max Drawdown Duration (days)': 90,
#    'Number of Trades': 20}),
#  (28.010446201072693,
#   'init rppo 1 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 28.010446201072693,
#    'Annualized Volatility [%]': 18.775752610414656,
#    'Max Drawdown [%]': -24.34088741184248,
#    'Average Drawdown [%]': -4.3421323404809264,
#    'Sharpe Ratio': 1.4123641922374,
#    'Sortino Ratio': 1.898892512790678,
#    'Calmar Ratio': 1.1507569846218866,
#    'Max Drawdown Duration (days)': 104,
#    'Number of Trades': 95}),
#  (27.704943402496028,
#   'init ppo 5 3 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 27.704943402496028,
#    'Annualized Volatility [%]': 21.46035530155816,
#    'Max Drawdown [%]': -25.48177785552544,
#    'Average Drawdown [%]': -5.239242602783031,
#    'Sharpe Ratio': 1.2498980033267248,
#    'Sortino Ratio': 1.6042314960444566,
#    'Calmar Ratio': 1.0872453075909898,
#    'Max Drawdown Duration (days)': 103,
#    'Number of Trades': 120}),
#  (27.517114047699145,
#   'init rppo 1 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 27.517114047699145,
#    'Annualized Volatility [%]': 19.093519361133445,
#    'Max Drawdown [%]': -23.462877266848903,
#    'Average Drawdown [%]': -4.6437987450149,
#    'Sharpe Ratio': 1.3719310745867834,
#    'Sortino Ratio': 1.7997050652512887,
#    'Calmar Ratio': 1.1727936746521082,
#    'Max Drawdown Duration (days)': 96,
#    'Number of Trades': 42}),
#  (27.49962901607483,
#   'init ppo 10 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 27.49962901607483,
#    'Annualized Volatility [%]': 20.351511202551222,
#    'Max Drawdown [%]': -24.94956542312072,
#    'Average Drawdown [%]': -5.206065382835869,
#    'Sharpe Ratio': 1.2986117802582269,
#    'Sortino Ratio': 1.6670569371365622,
#    'Calmar Ratio': 1.1022087378961307,
#    'Max Drawdown Duration (days)': 116,
#    'Number of Trades': 35}),
#  (27.44685302655334,
#   'init rppo 10 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 27.44685302655334,
#    'Annualized Volatility [%]': 20.962403785173283,
#    'Max Drawdown [%]': -26.022619231701572,
#    'Average Drawdown [%]': -5.237091370091589,
#    'Sharpe Ratio': 1.264709287999925,
#    'Sortino Ratio': 1.6772280591974074,
#    'Calmar Ratio': 1.0547306088664865,
#    'Max Drawdown Duration (days)': 105,
#    'Number of Trades': 72}),
#  (26.831349135274873,
#   'init ppo 4 3 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 26.831349135274873,
#    'Annualized Volatility [%]': 19.692297138528904,
#    'Max Drawdown [%]': -25.644084797686833,
#    'Average Drawdown [%]': -3.760507396004355,
#    'Sharpe Ratio': 1.307831459544248,
#    'Sortino Ratio': 1.712538337400707,
#    'Calmar Ratio': 1.0462977855109548,
#    'Max Drawdown Duration (days)': 103,
#    'Number of Trades': 179}),
#  (26.709100787964225,
#   'init ppo 8 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 26.709100787964225,
#    'Annualized Volatility [%]': 20.79739247006852,
#    'Max Drawdown [%]': -24.564320710867456,
#    'Average Drawdown [%]': -5.100632676416195,
#    'Sharpe Ratio': 1.245236809134867,
#    'Sortino Ratio': 1.6037427462278089,
#    'Calmar Ratio': 1.0873128185526375,
#    'Max Drawdown Duration (days)': 103,
#    'Number of Trades': 115}),
#  (25.56496672473172,
#   'init ppo 4 4',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 25.56496672473172,
#    'Annualized Volatility [%]': 19.80578503016538,
#    'Max Drawdown [%]': -24.14979227709811,
#    'Average Drawdown [%]': -4.983476923263912,
#    'Sharpe Ratio': 1.2514360402174076,
#    'Sortino Ratio': 1.5967149046773286,
#    'Calmar Ratio': 1.0585998600483058,
#    'Max Drawdown Duration (days)': 102,
#    'Number of Trades': 35}),
#  (25.422067539748294,
#   'init rppo 2 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 25.422067539748294,
#    'Annualized Volatility [%]': 16.864709720499345,
#    'Max Drawdown [%]': -20.88591743574744,
#    'Average Drawdown [%]': -3.7752778589716542,
#    'Sharpe Ratio': 1.431054320128177,
#    'Sortino Ratio': 1.807669921964962,
#    'Calmar Ratio': 1.217187016943626,
#    'Max Drawdown Duration (days)': 87,
#    'Number of Trades': 99}),
#  (25.04864225301937,
#   'init ppo 3 6 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 25.04864225301937,
#    'Annualized Volatility [%]': 20.32112063851039,
#    'Max Drawdown [%]': -24.398825908733283,
#    'Average Drawdown [%]': -3.5549925726798772,
#    'Sharpe Ratio': 1.203810801597993,
#    'Sortino Ratio': 1.626193248952858,
#    'Calmar Ratio': 1.0266330989333996,
#    'Max Drawdown Duration (days)': 110,
#    'Number of Trades': 152}),
#  (24.96408377034176,
#   'init ppo 4 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 24.96408377034176,
#    'Annualized Volatility [%]': 19.948968590226137,
#    'Max Drawdown [%]': -24.79805012036688,
#    'Average Drawdown [%]': -5.454964065904252,
#    'Sharpe Ratio': 1.2196005064315547,
#    'Sortino Ratio': 1.5724234437739923,
#    'Calmar Ratio': 1.0066954316637384,
#    'Max Drawdown Duration (days)': 131,
#    'Number of Trades': 47}),
#  (24.861469317572805,
#   'init rppo 1 3 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 24.861469317572805,
#    'Annualized Volatility [%]': 17.616694922910618,
#    'Max Drawdown [%]': -23.50626358253984,
#    'Average Drawdown [%]': -4.268519442242853,
#    'Sharpe Ratio': 1.351616538219351,
#    'Sortino Ratio': 1.752038875210309,
#    'Calmar Ratio': 1.057652962593323,
#    'Max Drawdown Duration (days)': 112,
#    'Number of Trades': 147}),
#  (24.749568913220465,
#   'init ppo 7 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 24.749568913220465,
#    'Annualized Volatility [%]': 20.52727603083836,
#    'Max Drawdown [%]': -22.323215490016736,
#    'Average Drawdown [%]': -5.1652164903449815,
#    'Sharpe Ratio': 1.182668782467583,
#    'Sortino Ratio': 1.5404025185718,
#    'Calmar Ratio': 1.1086919321407271,
#    'Max Drawdown Duration (days)': 132,
#    'Number of Trades': 62}),
#  (24.738469382188978,
#   'init rppo 2 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 24.738469382188978,
#    'Annualized Volatility [%]': 19.7382299336258,
#    'Max Drawdown [%]': -25.819185848245574,
#    'Average Drawdown [%]': -5.286559457036662,
#    'Sharpe Ratio': 1.2211436052320703,
#    'Sortino Ratio': 1.6463160952988432,
#    'Calmar Ratio': 0.9581428913983344,
#    'Max Drawdown Duration (days)': 114,
#    'Number of Trades': 80}),
#  (24.517208947960142,
#   'init ppo 4 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 24.517208947960142,
#    'Annualized Volatility [%]': 19.599505137230526,
#    'Max Drawdown [%]': -23.978808794286575,
#    'Average Drawdown [%]': -5.475924701608541,
#    'Sharpe Ratio': 1.2195032795918652,
#    'Sortino Ratio': 1.583090801911594,
#    'Calmar Ratio': 1.022453165138122,
#    'Max Drawdown Duration (days)': 131,
#    'Number of Trades': 155}),
#  (24.35382026307995,
#   'init ppo 1 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 24.35382026307995,
#    'Annualized Volatility [%]': 19.87060219302981,
#    'Max Drawdown [%]': -24.4520234173355,
#    'Average Drawdown [%]': -5.540103959325634,
#    'Sharpe Ratio': 1.1989150720260968,
#    'Sortino Ratio': 1.552771601064709,
#    'Calmar Ratio': 0.9959838434398878,
#    'Max Drawdown Duration (days)': 131,
#    'Number of Trades': 142}),
#  (24.002733089711747,
#   'init rppo 1 6 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 24.002733089711747,
#    'Annualized Volatility [%]': 17.90104403114792,
#    'Max Drawdown [%]': -22.53420572525666,
#    'Average Drawdown [%]': -4.353137263689732,
#    'Sharpe Ratio': 1.2946327618174305,
#    'Sortino Ratio': 1.6176684867197086,
#    'Calmar Ratio': 1.0651688096913547,
#    'Max Drawdown Duration (days)': 105,
#    'Number of Trades': 38}),
#  (23.90894221455482,
#   'init ppo 9 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.90894221455482,
#    'Annualized Volatility [%]': 21.105998995394337,
#    'Max Drawdown [%]': -26.90788060259074,
#    'Average Drawdown [%]': -6.074113581276959,
#    'Sharpe Ratio': 1.123507665880172,
#    'Sortino Ratio': 1.5002202920273175,
#    'Calmar Ratio': 0.8885479524631466,
#    'Max Drawdown Duration (days)': 131,
#    'Number of Trades': 128}),
#  (23.879101364366484,
#   'init rppo 4 3 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.879101364366484,
#    'Annualized Volatility [%]': 20.45414375952132,
#    'Max Drawdown [%]': -23.96069429603468,
#    'Average Drawdown [%]': -5.84823053868676,
#    'Sharpe Ratio': 1.151724755380312,
#    'Sortino Ratio': 1.5458840229623247,
#    'Calmar Ratio': 0.9965947175545034,
#    'Max Drawdown Duration (days)': 141,
#    'Number of Trades': 79}),
#  (23.83495137934943,
#   'init ppo 5 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.83495137934943,
#    'Annualized Volatility [%]': 16.42381596976535,
#    'Max Drawdown [%]': -22.602415399136905,
#    'Average Drawdown [%]': -3.9754927697580578,
#    'Sharpe Ratio': 1.3868346555846534,
#    'Sortino Ratio': 1.9265774261289377,
#    'Calmar Ratio': 1.0545311621986913,
#    'Max Drawdown Duration (days)': 108,
#    'Number of Trades': 73}),
#  (23.724605229291605,
#   'init ppo 3 1',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.724605229291605,
#    'Annualized Volatility [%]': 21.09154312343695,
#    'Max Drawdown [%]': -26.90848149447601,
#    'Average Drawdown [%]': -6.07538208898697,
#    'Sharpe Ratio': 1.117054421288326,
#    'Sortino Ratio': 1.4905127689453637,
#    'Calmar Ratio': 0.8816775942619424,
#    'Max Drawdown Duration (days)': 131,
#    'Number of Trades': 118}),
#  (23.471854160225725,
#   'init ppo 5 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.471854160225725,
#    'Annualized Volatility [%]': 21.394444138754924,
#    'Max Drawdown [%]': -24.079034672690387,
#    'Average Drawdown [%]': -5.73187646939133,
#    'Sharpe Ratio': 1.0951330835184796,
#    'Sortino Ratio': 1.3955970878159256,
#    'Calmar Ratio': 0.9747838515655568,
#    'Max Drawdown Duration (days)': 152,
#    'Number of Trades': 183}),
#  (23.398870051311626,
#   'init rppo 6 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.398870051311626,
#    'Annualized Volatility [%]': 17.43058381567101,
#    'Max Drawdown [%]': -23.583413060069056,
#    'Average Drawdown [%]': -4.602984549442507,
#    'Sharpe Ratio': 1.2960632543084034,
#    'Sortino Ratio': 1.7894148902731617,
#    'Calmar Ratio': 0.9921748812062366,
#    'Max Drawdown Duration (days)': 117,
#    'Number of Trades': 124}),
#  (23.346406701486444,
#   'init ppo 6 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.346406701486444,
#    'Annualized Volatility [%]': 21.38491319175605,
#    'Max Drawdown [%]': -24.076431112742185,
#    'Average Drawdown [%]': -5.731736800607724,
#    'Sharpe Ratio': 1.0907585354355538,
#    'Sortino Ratio': 1.3893406723330417,
#    'Calmar Ratio': 0.969678877744078,
#    'Max Drawdown Duration (days)': 152,
#    'Number of Trades': 189}),
#  (23.25632048586681,
#   'init rppo 2 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.25632048586681,
#    'Annualized Volatility [%]': 21.59193349066997,
#    'Max Drawdown [%]': -26.287044451736236,
#    'Average Drawdown [%]': -5.97507156181574,
#    'Sharpe Ratio': 1.078656603962166,
#    'Sortino Ratio': 1.4301736861408008,
#    'Calmar Ratio': 0.884706553015729,
#    'Max Drawdown Duration (days)': 136,
#    'Number of Trades': 80}),
#  (23.209522167867114,
#   'init rppo 5 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 23.209522167867114,
#    'Annualized Volatility [%]': 17.05207558876719,
#    'Max Drawdown [%]': -22.567492702645943,
#    'Average Drawdown [%]': -4.460638703598004,
#    'Sharpe Ratio': 1.3122977457424243,
#    'Sortino Ratio': 1.7152924853587643,
#    'Calmar Ratio': 1.028449304212953,
#    'Max Drawdown Duration (days)': 101,
#    'Number of Trades': 54}),
#  (22.949650566000667,
#   'init ppo 6 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 22.949650566000667,
#    'Annualized Volatility [%]': 19.102633877039935,
#    'Max Drawdown [%]': -21.62884598967705,
#    'Average Drawdown [%]': -7.094282504164607,
#    'Sharpe Ratio': 1.1798641852067095,
#    'Sortino Ratio': 1.576020696133403,
#    'Calmar Ratio': 1.061066807584372,
#    'Max Drawdown Duration (days)': 239,
#    'Number of Trades': 125}),
#  (22.81139276714747,
#   'init ppo 3 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 22.81139276714747,
#    'Annualized Volatility [%]': 20.590728255055975,
#    'Max Drawdown [%]': -23.331105118915495,
#    'Average Drawdown [%]': -5.425911673091388,
#    'Sharpe Ratio': 1.1035222807730911,
#    'Sortino Ratio': 1.4055913759752523,
#    'Calmar Ratio': 0.977724486297622,
#    'Max Drawdown Duration (days)': 142,
#    'Number of Trades': 162}),
#  (22.783598351782473,
#   'init ppo 3 4',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 22.783598351782473,
#    'Annualized Volatility [%]': 18.073908011898904,
#    'Max Drawdown [%]': -22.765909681653532,
#    'Average Drawdown [%]': -4.947142176835751,
#    'Sharpe Ratio': 1.2288829076412051,
#    'Sortino Ratio': 1.5810796356476755,
#    'Calmar Ratio': 1.00077698059846,
#    'Max Drawdown Duration (days)': 131,
#    'Number of Trades': 40}),
#  (22.2839386633072,
#   'init ppo 3 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 22.2839386633072,
#    'Annualized Volatility [%]': 22.848192233012856,
#    'Max Drawdown [%]': -26.06177297893567,
#    'Average Drawdown [%]': -6.71453165207115,
#    'Sharpe Ratio': 0.9968648238600968,
#    'Sortino Ratio': 1.3275428132539058,
#    'Calmar Ratio': 0.8550430809645264,
#    'Max Drawdown Duration (days)': 141,
#    'Number of Trades': 144}),
#  (22.2717586950234,
#   'init ppo 2 1',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 22.2717586950234,
#    'Annualized Volatility [%]': 22.844664133463255,
#    'Max Drawdown [%]': -26.064221516763652,
#    'Average Drawdown [%]': -6.713638985234763,
#    'Sharpe Ratio': 0.9965476649884892,
#    'Sortino Ratio': 1.3268218306027384,
#    'Calmar Ratio': 0.8544954500443812,
#    'Max Drawdown Duration (days)': 141,
#    'Number of Trades': 151}),
#  (21.937446639271418,
#   'init rppo 1 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 21.937446639271418,
#    'Annualized Volatility [%]': 16.841881157681122,
#    'Max Drawdown [%]': -22.563830355561574,
#    'Average Drawdown [%]': -4.545357791932184,
#    'Sharpe Ratio': 1.264481351818824,
#    'Sortino Ratio': 1.7426011334746243,
#    'Calmar Ratio': 0.9722394776764588,
#    'Max Drawdown Duration (days)': 117,
#    'Number of Trades': 137}),
#  (21.89619382961474,
#   'init rppo 4 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 21.89619382961474,
#    'Annualized Volatility [%]': 21.456210858780356,
#    'Max Drawdown [%]': -24.062667721120544,
#    'Average Drawdown [%]': -6.000525271565641,
#    'Sharpe Ratio': 1.0325341104661268,
#    'Sortino Ratio': 1.3253822516874578,
#    'Calmar Ratio': 0.9099653489540472,
#    'Max Drawdown Duration (days)': 152,
#    'Number of Trades': 77}),
#  (21.84615122321427,
#   'init rppo 6 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 21.84615122321427,
#    'Annualized Volatility [%]': 19.58404923548484,
#    'Max Drawdown [%]': -25.031813371261535,
#    'Average Drawdown [%]': -5.860366722305644,
#    'Sharpe Ratio': 1.1089099793164316,
#    'Sortino Ratio': 1.5157284065970356,
#    'Calmar Ratio': 0.8727354626371315,
#    'Max Drawdown Duration (days)': 133,
#    'Number of Trades': 107}),
#  (21.608255062142455,
#   'init ppo 4 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 21.608255062142455,
#    'Annualized Volatility [%]': 21.811840871246343,
#    'Max Drawdown [%]': -24.909978991557537,
#    'Average Drawdown [%]': -6.566127419433264,
#    'Sharpe Ratio': 1.008334289046822,
#    'Sortino Ratio': 1.3394451106467726,
#    'Calmar Ratio': 0.8674537649937762,
#    'Max Drawdown Duration (days)': 141,
#    'Number of Trades': 138}),
#  (21.464496663362187,
#   'init ppo 3 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 21.464496663362187,
#    'Annualized Volatility [%]': 16.655441018664728,
#    'Max Drawdown [%]': -22.17073141507258,
#    'Average Drawdown [%]': -4.497731996953036,
#    'Sharpe Ratio': 1.253368467350624,
#    'Sortino Ratio': 1.727743402030889,
#    'Calmar Ratio': 0.9681456268406976,
#    'Max Drawdown Duration (days)': 117,
#    'Number of Trades': 147}),
#  (21.204274531812462,
#   'init rppo 4 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 21.204274531812462,
#    'Annualized Volatility [%]': 16.633147525125356,
#    'Max Drawdown [%]': -22.140516514204283,
#    'Average Drawdown [%]': -4.489555297162248,
#    'Sharpe Ratio': 1.2418902304467985,
#    'Sortino Ratio': 1.7130889430332736,
#    'Calmar Ratio': 0.9577136341064504,
#    'Max Drawdown Duration (days)': 117,
#    'Number of Trades': 150}),
#  (21.175972002881306,
#   'init ppo 7 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 21.175972002881306,
#    'Annualized Volatility [%]': 21.584585992900724,
#    'Max Drawdown [%]': -24.558643988479098,
#    'Average Drawdown [%]': -6.495024901921163,
#    'Sharpe Ratio': 1.000039939273098,
#    'Sortino Ratio': 1.3315357122780829,
#    'Calmar Ratio': 0.8622614511133163,
#    'Max Drawdown Duration (days)': 141,
#    'Number of Trades': 133}),
#  (20.977899903953,
#   'init ppo 2 4',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 20.977899903953,
#    'Annualized Volatility [%]': 18.137082516668464,
#    'Max Drawdown [%]': -24.237452213925273,
#    'Average Drawdown [%]': -4.935164595807617,
#    'Sharpe Ratio': 1.1431857590127492,
#    'Sortino Ratio': 1.4782085328423362,
#    'Calmar Ratio': 0.8655158850359881,
#    'Max Drawdown Duration (days)': 131,
#    'Number of Trades': 20}),
#  (20.78207008110473,
#   'init rppo 7 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 20.78207008110473,
#    'Annualized Volatility [%]': 21.15899002929616,
#    'Max Drawdown [%]': -26.01727060736405,
#    'Average Drawdown [%]': -6.62454804626373,
#    'Sharpe Ratio': 0.9999752812864312,
#    'Sortino Ratio': 1.350136616058773,
#    'Calmar Ratio': 0.7987797949575263,
#    'Max Drawdown Duration (days)': 143,
#    'Number of Trades': 99}),
#  (20.384814071758672,
#   'init ppo 1 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 20.384814071758672,
#    'Annualized Volatility [%]': 20.044619060060217,
#    'Max Drawdown [%]': -20.545465686712028,
#    'Average Drawdown [%]': -8.439511645021911,
#    'Sharpe Ratio': 1.02799836818267,
#    'Sortino Ratio': 1.3833056687890386,
#    'Calmar Ratio': 0.9921806778486768,
#    'Max Drawdown Duration (days)': 347,
#    'Number of Trades': 151}),
#  (20.23646918587243,
#   'init ppo 1 3 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 20.23646918587243,
#    'Annualized Volatility [%]': 16.655191902681615,
#    'Max Drawdown [%]': -22.139288245573095,
#    'Average Drawdown [%]': -4.488254962188885,
#    'Sharpe Ratio': 1.192200358843582,
#    'Sortino Ratio': 1.634156384261748,
#    'Calmar Ratio': 0.9140523833199043,
#    'Max Drawdown Duration (days)': 117,
#    'Number of Trades': 149}),
#  (20.18023326925138,
#   'init rppo 5 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 20.18023326925138,
#    'Annualized Volatility [%]': 16.16975778304859,
#    'Max Drawdown [%]': -21.56488245405353,
#    'Average Drawdown [%]': -4.418561304403543,
#    'Sharpe Ratio': 1.2201471731542852,
#    'Sortino Ratio': 1.6891548527208469,
#    'Calmar Ratio': 0.9357914800717182,
#    'Max Drawdown Duration (days)': 152,
#    'Number of Trades': 138}),
#  (20.09724252679208,
#   'init ppo 2 6 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 20.09724252679208,
#    'Annualized Volatility [%]': 18.394510984662407,
#    'Max Drawdown [%]': -19.84544448617013,
#    'Average Drawdown [%]': -6.644098491355541,
#    'Sharpe Ratio': 1.0898643358509408,
#    'Sortino Ratio': 1.4508240319030044,
#    'Calmar Ratio': 1.0126879516756313,
#    'Max Drawdown Duration (days)': 282,
#    'Number of Trades': 140}),
#  (19.861234431038888,
#   'init rppo 7 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 19.861234431038888,
#    'Annualized Volatility [%]': 21.05927180754087,
#    'Max Drawdown [%]': -25.710169671837136,
#    'Average Drawdown [%]': -6.785903274173164,
#    'Sharpe Ratio': 0.9671636146059563,
#    'Sortino Ratio': 1.3177927450813165,
#    'Calmar Ratio': 0.7725049925592222,
#    'Max Drawdown Duration (days)': 143,
#    'Number of Trades': 122}),
#  (19.583518976552327,
#   'init ppo 1 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 19.583518976552327,
#    'Annualized Volatility [%]': 20.376984941413863,
#    'Max Drawdown [%]': -28.62876519418929,
#    'Average Drawdown [%]': -5.804137847287313,
#    'Sharpe Ratio': 0.981479694370042,
#    'Sortino Ratio': 1.304462950233029,
#    'Calmar Ratio': 0.6840504242399928,
#    'Max Drawdown Duration (days)': 128,
#    'Number of Trades': 15}),
#  (19.34363462407811,
#   'init rppo 3 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 19.34363462407811,
#    'Annualized Volatility [%]': 19.861855684434207,
#    'Max Drawdown [%]': -23.074674411210957,
#    'Average Drawdown [%]': -6.377764959715095,
#    'Sharpe Ratio': 0.9917469015778324,
#    'Sortino Ratio': 1.3030242964504417,
#    'Calmar Ratio': 0.8383058533939659,
#    'Max Drawdown Duration (days)': 248,
#    'Number of Trades': 70}),
#  (19.067036019811724,
#   'init ppo 9 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 19.067036019811724,
#    'Annualized Volatility [%]': 21.775425107906702,
#    'Max Drawdown [%]': -25.818167327890617,
#    'Average Drawdown [%]': -7.640134719076553,
#    'Sharpe Ratio': 0.911814668628966,
#    'Sortino Ratio': 1.237378084214821,
#    'Calmar Ratio': 0.7385123729992313,
#    'Max Drawdown Duration (days)': 254,
#    'Number of Trades': 99}),
#  (18.85000393082279,
#   'init ppo 2 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.85000393082279,
#    'Annualized Volatility [%]': 21.91083891863063,
#    'Max Drawdown [%]': -25.643347388464377,
#    'Average Drawdown [%]': -7.7844182282287555,
#    'Sharpe Ratio': 0.8991420930323323,
#    'Sortino Ratio': 1.2247700886406243,
#    'Calmar Ratio': 0.7350835928425802,
#    'Max Drawdown Duration (days)': 256,
#    'Number of Trades': 145}),
#  (18.83032400266691,
#   'init ppo 1 4',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.83032400266691,
#    'Annualized Volatility [%]': 16.331786816833898,
#    'Max Drawdown [%]': -19.96603512066593,
#    'Average Drawdown [%]': -4.432458431012676,
#    'Sharpe Ratio': 1.1406883834628485,
#    'Sortino Ratio': 1.464252887203869,
#    'Calmar Ratio': 0.9431178443223563,
#    'Max Drawdown Duration (days)': 135,
#    'Number of Trades': 63}),
#  (18.81545807178078,
#   'init ppo 1 6 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.81545807178078,
#    'Annualized Volatility [%]': 21.914057595826243,
#    'Max Drawdown [%]': -25.643735525022652,
#    'Average Drawdown [%]': -7.793320505439164,
#    'Sharpe Ratio': 0.8977096380131654,
#    'Sortino Ratio': 1.2232152009524364,
#    'Calmar Ratio': 0.7337253206897655,
#    'Max Drawdown Duration (days)': 256,
#    'Number of Trades': 154}),
#  (18.773455543497008,
#   'init ppo 1 1',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.773455543497008,
#    'Annualized Volatility [%]': 21.908205381814835,
#    'Max Drawdown [%]': -25.646239734928255,
#    'Average Drawdown [%]': -7.788873798540232,
#    'Sharpe Ratio': 0.8962745122669803,
#    'Sortino Ratio': 1.220762757141263,
#    'Calmar Ratio': 0.7320159110081533,
#    'Max Drawdown Duration (days)': 256,
#    'Number of Trades': 146}),
#  (18.75560887560503,
#   'init ppo 2 3 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.75560887560503,
#    'Annualized Volatility [%]': 21.9052382049581,
#    'Max Drawdown [%]': -25.64158500110882,
#    'Average Drawdown [%]': -7.791985532313269,
#    'Sharpe Ratio': 0.8956786587030677,
#    'Sortino Ratio': 1.219962807367377,
#    'Calmar Ratio': 0.7314527894743631,
#    'Max Drawdown Duration (days)': 256,
#    'Number of Trades': 146}),
#  (18.64669861174579,
#   'init ppo 1 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.64669861174579,
#    'Annualized Volatility [%]': 21.896999009253648,
#    'Max Drawdown [%]': -25.643986239030376,
#    'Average Drawdown [%]': -7.78914250255382,
#    'Sharpe Ratio': 0.8917324002327731,
#    'Sortino Ratio': 1.2140525969140632,
#    'Calmar Ratio': 0.7271372881711093,
#    'Max Drawdown Duration (days)': 256,
#    'Number of Trades': 139}),
#  (18.331839120489835,
#   'init ppo 2 3 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.331839120489835,
#    'Annualized Volatility [%]': 21.96943354190395,
#    'Max Drawdown [%]': -25.642341881355208,
#    'Average Drawdown [%]': -7.785388884205694,
#    'Sharpe Ratio': 0.8773767975218782,
#    'Sortino Ratio': 1.2018411226216952,
#    'Calmar Ratio': 0.7149050272127871,
#    'Max Drawdown Duration (days)': 290,
#    'Number of Trades': 150}),
#  (18.236284881392308,
#   'init ppo 4 1',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.236284881392308,
#    'Annualized Volatility [%]': 21.881235543839047,
#    'Max Drawdown [%]': -25.642894277470425,
#    'Average Drawdown [%]': -7.790039025213308,
#    'Sharpe Ratio': 0.8763341270865023,
#    'Sortino Ratio': 1.1924578750636652,
#    'Calmar Ratio': 0.7111632830547726,
#    'Max Drawdown Duration (days)': 256,
#    'Number of Trades': 153}),
#  (18.14445273047765,
#   'init rppo 3 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 18.14445273047765,
#    'Annualized Volatility [%]': 21.183503133675433,
#    'Max Drawdown [%]': -24.96544087019931,
#    'Average Drawdown [%]': -7.505402083713873,
#    'Sharpe Ratio': 0.8945072953770425,
#    'Sortino Ratio': 1.215994725565802,
#    'Calmar Ratio': 0.7267827884480211,
#    'Max Drawdown Duration (days)': 256,
#    'Number of Trades': 145}),
#  (17.553335228426505,
#   'init rppo 2 3 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 17.553335228426505,
#    'Annualized Volatility [%]': 20.51234166416423,
#    'Max Drawdown [%]': -24.50382832250077,
#    'Average Drawdown [%]': -7.3634940466528835,
#    'Sharpe Ratio': 0.8924896039768262,
#    'Sortino Ratio': 1.208533230249858,
#    'Calmar Ratio': 0.7163507268090049,
#    'Max Drawdown Duration (days)': 255,
#    'Number of Trades': 148}),
#  (17.535184286486484,
#   'init rppo 8 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 17.535184286486484,
#    'Annualized Volatility [%]': 21.69026010165564,
#    'Max Drawdown [%]': -24.512202801152757,
#    'Average Drawdown [%]': -8.222369103968546,
#    'Sharpe Ratio': 0.8548774406836241,
#    'Sortino Ratio': 1.1428085219774569,
#    'Calmar Ratio': 0.7153655030000747,
#    'Max Drawdown Duration (days)': 289,
#    'Number of Trades': 86}),
#  (16.850441937089467,
#   'init ppo 4 3 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 16.850441937089467,
#    'Annualized Volatility [%]': 16.822274204501515,
#    'Max Drawdown [%]': -19.691537606442058,
#    'Average Drawdown [%]': -4.951949757271319,
#    'Sharpe Ratio': 1.0120556319481906,
#    'Sortino Ratio': 1.3486876331098256,
#    'Calmar Ratio': 0.8557199683368999,
#    'Max Drawdown Duration (days)': 141,
#    'Number of Trades': 201}),
#  (14.111239587722936,
#   'init rppo 4 1 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 14.111239587722936,
#    'Annualized Volatility [%]': 20.508034811071095,
#    'Max Drawdown [%]': -26.052946324231364,
#    'Average Drawdown [%]': -8.806360415819936,
#    'Sharpe Ratio': 0.7475465578381855,
#    'Sortino Ratio': 0.9932461336646006,
#    'Calmar Ratio': 0.5416369961426717,
#    'Max Drawdown Duration (days)': 386,
#    'Number of Trades': 30}),
#  (13.99065435594844,
#   'init ppo 2 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 13.99065435594844,
#    'Annualized Volatility [%]': 16.115274595070694,
#    'Max Drawdown [%]': -19.389080927894568,
#    'Average Drawdown [%]': -5.734148610694204,
#    'Sharpe Ratio': 0.8948126712490805,
#    'Sortino Ratio': 1.218686838662376,
#    'Calmar Ratio': 0.7215738800605267,
#    'Max Drawdown Duration (days)': 256,
#    'Number of Trades': 193}),
#  (13.10084830694267,
#   'init ppo 2 1 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 13.10084830694267,
#    'Annualized Volatility [%]': 19.908918278227556,
#    'Max Drawdown [%]': -24.039612348718947,
#    'Average Drawdown [%]': -9.166412116457805,
#    'Sharpe Ratio': 0.7192505855236854,
#    'Sortino Ratio': 0.9622112834022276,
#    'Calmar Ratio': 0.5449691998731753,
#    'Max Drawdown Duration (days)': 362,
#    'Number of Trades': 165}),
#  (12.492682320258886,
#   'init ppo 4 1 True',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 12.492682320258886,
#    'Annualized Volatility [%]': 19.872863976616788,
#    'Max Drawdown [%]': -24.11695579228063,
#    'Average Drawdown [%]': -9.186476393381016,
#    'Sharpe Ratio': 0.6929916269133382,
#    'Sortino Ratio': 0.92538618565051,
#    'Calmar Ratio': 0.5180041141120121,
#    'Max Drawdown Duration (days)': 362,
#    'Number of Trades': 185}),
#  (12.416913270424269,
#   'init ppo 3 3 False risk-reward',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 12.416913270424269,
#    'Annualized Volatility [%]': 19.590818621816215,
#    'Max Drawdown [%]': -23.982402046170076,
#    'Average Drawdown [%]': -9.297517477836088,
#    'Sharpe Ratio': 0.6966835059022736,
#    'Sortino Ratio': 0.9343505172799405,
#    'Calmar Ratio': 0.5177510262116223,
#    'Max Drawdown Duration (days)': 366,
#    'Number of Trades': 88}),
#  (12.377316680298357,
#   'init ppo 5 3 False',
#   {'Start': '2023-01-03T00:00:00',
#    'End': '2025-08-29T00:00:00',
#    'Annualized Return [%]': 12.377316680298357,
#    'Annualized Volatility [%]': 19.648682387839393,
#    'Max Drawdown [%]': -24.505604028071783,
#    'Average Drawdown [%]': -9.445808219680726,
#    'Sharpe Ratio': 0.6934386629012536,
#    'Sortino Ratio': 0.9271858486627232,
#    'Calmar Ratio': 0.5050810690534226,
#    'Max Drawdown Duration (days)': 366,
#    'Number of Trades': 120})]

# %%
ppo\single\norm\raw      init ppo 8 1 False                      
rppo\single\norm\raw     init rppo 9 1 False
rppo\single\norm\risk    init rppo 3 1 False risk-reward
rppo\single\rand\raw     init rppo 1 1 True
rppo\vec\norm\raw        init rppo 5 3 False
rppo\vec\norm\risk       init rppo 2 3 False risk-reward
rppo\vec\rand\raw        init rppo 4 3 True
# Out:
#   Cell In[25], line 1
#     ppo\single\norm\raw      init ppo 8 1 False
#         ^
# SyntaxError: unexpected character after line continuation character

# %%
print([x for x in best if x[1] == 'init ppo 8 1 False'])

print([x for x in best if x[1] == 'init rppo 9 1 False'])
print([x for x in best if x[1] == 'init rppo 3 1 False risk-reward'])
print([x for x in best if x[1] == 'init rppo 1 1 True'])

print([x for x in best if x[1] == 'init rppo 5 3 False'])
print([x for x in best if x[1] == 'init rppo 2 3 False risk-reward'])
print([x for x in best if x[1] == 'init rppo 4 3 True'])
# Out:
# [(35.169709976361304, 'init ppo 8 1 False', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 35.169709976361304, 'Annualized Volatility [%]': 21.21322876470389, 'Max Drawdown [%]': -25.34914648279225, 'Average Drawdown [%]': -4.8373454651483945, 'Sharpe Ratio': 1.5303760750095827, 'Sortino Ratio': 1.9980492091333124, 'Calmar Ratio': 1.387411998279135, 'Max Drawdown Duration (days)': 103, 'Number of Trades': 132})]
# [(30.04683303942248, 'init rppo 9 1 False', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 30.04683303942248, 'Annualized Volatility [%]': 20.334939920060037, 'Max Drawdown [%]': -25.36573813640817, 'Average Drawdown [%]': -4.710348243204692, 'Sharpe Ratio': 1.3969395656850383, 'Sortino Ratio': 1.860373300265335, 'Calmar Ratio': 1.1845440049030311, 'Max Drawdown Duration (days)': 105, 'Number of Trades': 75})]
# [(30.841394185513813, 'init rppo 3 1 False risk-reward', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 30.841394185513813, 'Annualized Volatility [%]': 20.31607066639417, 'Max Drawdown [%]': -27.653748530300295, 'Average Drawdown [%]': -4.6957898104085825, 'Sharpe Ratio': 1.4278959343339157, 'Sortino Ratio': 1.9513405616336037, 'Calmar Ratio': 1.1152699299236342, 'Max Drawdown Duration (days)': 108, 'Number of Trades': 105})]
# [(28.010446201072693, 'init rppo 1 1 True', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 28.010446201072693, 'Annualized Volatility [%]': 18.775752610414656, 'Max Drawdown [%]': -24.34088741184248, 'Average Drawdown [%]': -4.3421323404809264, 'Sharpe Ratio': 1.4123641922374, 'Sortino Ratio': 1.898892512790678, 'Calmar Ratio': 1.1507569846218866, 'Max Drawdown Duration (days)': 104, 'Number of Trades': 95})]
# [(31.31094618547727, 'init rppo 5 3 False', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 31.31094618547727, 'Annualized Volatility [%]': 20.568429591120772, 'Max Drawdown [%]': -27.78702606795158, 'Average Drawdown [%]': -4.732719932515637, 'Sharpe Ratio': 1.43028199035609, 'Sortino Ratio': 1.9778261790092135, 'Calmar Ratio': 1.126818901342956, 'Max Drawdown Duration (days)': 108, 'Number of Trades': 120})]
# [(30.38817470310411, 'init rppo 2 3 False risk-reward', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 30.38817470310411, 'Annualized Volatility [%]': 20.43041675365319, 'Max Drawdown [%]': -27.80345020414796, 'Average Drawdown [%]': -4.829025040591292, 'Sharpe Ratio': 1.4039862032916866, 'Sortino Ratio': 1.9232944982622069, 'Calmar Ratio': 1.0929641637990144, 'Max Drawdown Duration (days)': 108, 'Number of Trades': 142})]
# [(30.16004923089397, 'init rppo 4 3 True', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 30.16004923089397, 'Annualized Volatility [%]': 18.402878399689097, 'Max Drawdown [%]': -22.678496207993796, 'Average Drawdown [%]': -3.7580106348562023, 'Sharpe Ratio': 1.527850191420416, 'Sortino Ratio': 2.103895541886817, 'Calmar Ratio': 1.3298963456079178, 'Max Drawdown Duration (days)': 93, 'Number of Trades': 57})]

# %%
print([x for x in best if x[1] == 'init ppo 5 1 False risk-reward'])
# Out:
# [(33.90782175234646, 'init ppo 5 1 False risk-reward', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 33.90782175234646, 'Annualized Volatility [%]': 22.12884399318141, 'Max Drawdown [%]': -26.075984851644236, 'Average Drawdown [%]': -4.5975205827425825, 'Sharpe Ratio': 1.432827118432097, 'Sortino Ratio': 1.9430151883289384, 'Calmar Ratio': 1.3003467345628703, 'Max Drawdown Duration (days)': 103, 'Number of Trades': 126})]

# %%
print([x for x in best if x[1] == 'init ppo 1 3 False risk-reward'])
# Out:
# [(30.30876536175471, 'init ppo 1 3 False risk-reward', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 30.30876536175471, 'Annualized Volatility [%]': 22.116764363408357, 'Max Drawdown [%]': -26.06825550989625, 'Average Drawdown [%]': -4.907151114529311, 'Sharpe Ratio': 1.3106745307626717, 'Sortino Ratio': 1.755910950723051, 'Calmar Ratio': 1.1626694908774635, 'Max Drawdown Duration (days)': 99, 'Number of Trades': 126})]

# %%
print([x for x in best if x[1] == 'init rppo 1 1 True'])
# Out:
# [(28.010446201072693, 'init rppo 1 1 True', {'Start': '2023-01-03T00:00:00', 'End': '2025-08-29T00:00:00', 'Annualized Return [%]': 28.010446201072693, 'Annualized Volatility [%]': 18.775752610414656, 'Max Drawdown [%]': -24.34088741184248, 'Average Drawdown [%]': -4.3421323404809264, 'Sharpe Ratio': 1.4123641922374, 'Sortino Ratio': 1.898892512790678, 'Calmar Ratio': 1.1507569846218866, 'Max Drawdown Duration (days)': 104, 'Number of Trades': 95})]
